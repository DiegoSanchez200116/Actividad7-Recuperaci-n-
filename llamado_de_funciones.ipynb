# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import importlib
import funciones as f
importlib.reload(f)
# Out:
# <module 'funciones' from '/Users/diego/Desktop/IA/Alfredy/Actividad7/funciones.py'>

# %% [markdown]
# ### Función_1

# %%
df = f.cargar_dataset('Portugal.csv')

# %%
pd.options.display.max_rows= None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6246 entries, 0 to 6245
# Data columns (total 51 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   Unnamed: 0                                    6246 non-null   int64
#  1   id                                            6246 non-null   int64
#  2   name                                          6246 non-null   object
#  3   host_id                                       6246 non-null   int64
#  4   host_name                                     6246 non-null   object
#  5   host_since                                    6246 non-null   object
#  6   host_response_time                            5523 non-null   object
#  7   host_response_rate                            5523 non-null   object
#  8   host_acceptance_rate                          5728 non-null   object
# ...

# %%
valores_nulos = f.cuenta_nulos(df)
valores_nulos
# Out:
# ('Valores nulos por columna',
#  Unnamed: 0                                         0
#  id                                                 0
#  name                                               0
#  host_id                                            0
#  host_name                                          0
#  host_since                                         0
#  host_response_time                               723
#  host_response_rate                               723
#  host_acceptance_rate                             518
#  host_is_superhost                                104
#  host_listings_count                                0
#  host_identity_verified                             0
#  neighbourhood_cleansed                             0
#  neighbourhood_group_cleansed                    6246
#  latitude                                           0
#  longitude                                          0
#  property_type                                      0
# ...

# %%
#Borramos columnas que no nos interesan
df = df.drop(columns=['Unnamed: 0', 'neighbourhood_group_cleansed'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6246 entries, 0 to 6245
# Data columns (total 49 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            6246 non-null   int64
#  1   name                                          6246 non-null   object
#  2   host_id                                       6246 non-null   int64
#  3   host_name                                     6246 non-null   object
#  4   host_since                                    6246 non-null   object
#  5   host_response_time                            5523 non-null   object
#  6   host_response_rate                            5523 non-null   object
#  7   host_acceptance_rate                          5728 non-null   object
#  8   host_is_superhost                             6142 non-null   object
# ...

# %% [markdown]
# ### Función_2

# %%
df_sin_nulos = f.limpieza_nulos(df)

# %%
valores_nulos = f.cuenta_nulos(df_sin_nulos)
valores_nulos
# Out:
# ('Valores nulos por columna',
#  id                                              0
#  host_id                                         0
#  longitude                                       0
#  bathrooms                                       0
#  bedrooms                                        0
#  maximum_nights                                  0
#  maximum_nights_avg_ntm                          0
#  availability_30                                 0
#  number_of_reviews_l30d                          0
#  review_scores_checkin                           0
#  review_scores_location                          0
#  calculated_host_listings_count_entire_homes     0
#  host_listings_count                             0
#  latitude                                        0
#  accommodates                                    0
#  beds                                            0
#  minimum_nights                                  0
#  minimum_minimum_nights                          0
# ...

# %% [markdown]
# ### Función_3

# %%
valores_nulos = f.cuenta_nulos(df_sin_nulos)
valores_nulos
# Out:
# ('Valores nulos por columna',
#  id                                              0
#  host_id                                         0
#  longitude                                       0
#  bathrooms                                       0
#  bedrooms                                        0
#  maximum_nights                                  0
#  maximum_nights_avg_ntm                          0
#  availability_30                                 0
#  number_of_reviews_l30d                          0
#  review_scores_checkin                           0
#  review_scores_location                          0
#  calculated_host_listings_count_entire_homes     0
#  host_listings_count                             0
#  latitude                                        0
#  accommodates                                    0
#  beds                                            0
#  minimum_nights                                  0
#  minimum_minimum_nights                          0
# ...

# %% [markdown]
# ### Función_4

# %%
df_procesado = f.sust_atipicos(df_sin_nulos)
df_procesado.head(5)
# Out:
#                                              name  host_name  \
# 0                               Byron Beach Cabin       Glen
# 1                              Tea on the Terrace        Liz
# 2      5 Star Luxury @ Tweed Coast - Salt Village     Tricia
# 3  Byron Bay Hinterland House & Pool POCKET PINES         Jo
# 4                              Rosebank Farmhouse  Ann-Marie
#
#   host_response_time host_acceptance_rate   neighbourhood_cleansed  \
# 0     within an hour                  83%      BYRON SHIRE COUNCIL
# 1     within an hour                  93%  CLARENCE VALLEY COUNCIL
# 2     within an hour                  96%      TWEED SHIRE COUNCIL
# 3     within an hour                  95%      BYRON SHIRE COUNCIL
# 4     within an hour                 100%     LISMORE CITY COUNCIL
#
#    host_since host_response_rate host_is_superhost host_identity_verified  \
# 0  2010-08-21               100%                 f                      t
# ...

# %%
valores_nulos = f.cuenta_nulos(df_procesado)
valores_nulos
# Out:
# ('Valores nulos por columna',
#  name                                            0
#  host_name                                       0
#  host_response_time                              0
#  host_acceptance_rate                            0
#  neighbourhood_cleansed                          0
#  host_since                                      0
#  host_response_rate                              0
#  host_is_superhost                               0
#  host_identity_verified                          0
#  property_type                                   0
#  room_type                                       0
#  bathrooms_text                                  0
#  price                                           0
#  has_availability                                0
#  instant_bookable                                0
#  id                                              0
#  host_id                                         0
#  longitude                                       0
# ...

# %%
#Convertir DataFrame a CSV
df_procesado.to_csv('Portugal_procesado.csv')
